# %%
import os
import pandas as pd

# %%
titanic = pd.read_csv("titanic_data_set.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.columns = ["Id_Passageiro", "Sobrevivente", "Classe", "Nome", "Sexo", "Idade", "Irmao_ou_Conjuge", "Filhos", "Ingresso", "Tarifa", "Cabine", "Portao_embarque"]

# %%
titanic.to_excel("titanicexcel.xlsx", sheet_name="passageiros", index=False)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id_Passageiro     891 non-null    int64
#  1   Sobrevivente      891 non-null    int64
#  2   Classe            891 non-null    int64
#  3   Nome              891 non-null    object
#  4   Sexo              891 non-null    object
#  5   Idade             714 non-null    float64
#  6   Irmao_ou_Conjuge  891 non-null    int64
#  7   Filhos            891 non-null    int64
#  8   Ingresso          891 non-null    object
#  9   Tarifa            891 non-null    float64
#  10  Cabine            204 non-null    object
#  11  Portao_embarque   889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
idades = titanic["Idade"]

# %%
idades.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Idade, dtype: float64

# %%
type(titanic["Idade"])
# Out:
# pandas.core.series.Series

# %%
titanic["Idade"].shape
# Out:
# (891,)

# %%
idade_sexo = titanic[["Nome","Idade", "Sexo"]]

# %%
idade_sexo.head()
# Out:
#                                                 Nome  Idade    Sexo
# 0                            Braund, Mr. Owen Harris   22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   38.0  female
# 2                              Heikkinen, Miss Laina   26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   35.0  female
# 4                           Allen, Mr. William Henry   35.0    male

# %%
type(titanic[["Idade", "Sexo"]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic[["Idade", "Sexo"]].shape
# Out:
# (891, 2)

# %%
idade_35 = titanic[titanic["Idade"] > 35]

# %%
idade_35.head()
# Out:
#     Id_Passageiro  Sobrevivente  Classe  \
# 1               2             1       1
# 6               7             0       1
# 11             12             1       1
# 13             14             0       3
# 15             16             1       2
#
#                                                  Nome    Sexo  Idade  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 6                             McCarthy, Mr. Timothy J    male   54.0
# 11                            Bonnell, Miss Elizabeth  female   58.0
# 13                        Andersson, Mr. Anders Johan    male   39.0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female   55.0
#
#     Irmao_ou_Conjuge  Filhos  Ingresso   Tarifa Cabine Portao_embarque
# 1                  1       0  PC 17599  71.2833    C85               C
# 6                  0       0     17463  51.8625    E46               S
# 11                 0       0    113783  26.5500   C103               S
# ...

# %%
titanic["Idade"] >= 35
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Idade, Length: 891, dtype: bool

# %%
idade_35.shape
# Out:
# (217, 12)

# %%
classe_23 = titanic[titanic["Classe"].isin([2, 3])]

# %%
classe_23.head()
# Out:
#    Id_Passageiro  Sobrevivente  Classe                           Nome    Sexo  \
# 0              1             0       3        Braund, Mr. Owen Harris    male
# 2              3             1       3          Heikkinen, Miss Laina  female
# 4              5             0       3       Allen, Mr. William Henry    male
# 5              6             0       3               Moran, Mr. James    male
# 7              8             0       3  Palsson, Master Gosta Leonard    male
#
#    Idade  Irmao_ou_Conjuge  Filhos          Ingresso   Tarifa Cabine  \
# 0   22.0                 1       0         A/5 21171   7.2500    NaN
# 2   26.0                 0       0  STON/O2. 3101282   7.9250    NaN
# 4   35.0                 0       0            373450   8.0500    NaN
# 5    NaN                 0       0            330877   8.4583    NaN
# 7    2.0                 3       1            349909  21.0750    NaN
#
#   Portao_embarque
# 0               S
# 2               S
# 4               S
# ...

# %%
# | ou or são iguais ao OU e & ou and são iguais a E
classe_23 = titanic[(titanic["Classe"] == 2) | (titanic["Classe"] == 3)]

# %%
classe_23
# Out:
#      Id_Passageiro  Sobrevivente  Classe  \
# 0                1             0       3
# 2                3             1       3
# 4                5             0       3
# 5                6             0       3
# 7                8             0       3
# ..             ...           ...     ...
# 884            885             0       3
# 885            886             0       3
# 886            887             0       2
# 888            889             0       3
# 890            891             0       3
#
#                                         Nome    Sexo  Idade  Irmao_ou_Conjuge  \
# 0                    Braund, Mr. Owen Harris    male   22.0                 1
# 2                      Heikkinen, Miss Laina  female   26.0                 0
# 4                   Allen, Mr. William Henry    male   35.0                 0
# 5                           Moran, Mr. James    male    NaN                 0
# ...

# %%
idade_nao_nan = titanic[titanic["Idade"].notna()]

# %%
idade_nao_nan.head()
# Out:
#    Id_Passageiro  Sobrevivente  Classe  \
# 0              1             0       3
# 1              2             1       1
# 2              3             1       3
# 3              4             1       1
# 4              5             0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                              Heikkinen, Miss Laina  female   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                           Allen, Mr. William Henry    male   35.0
#
#    Irmao_ou_Conjuge  Filhos          Ingresso   Tarifa Cabine Portao_embarque
# 0                 1       0         A/5 21171   7.2500    NaN               S
# 1                 1       0          PC 17599  71.2833    C85               C
# 2                 0       0  STON/O2. 3101282   7.9250    NaN               S
# ...

# %%
idade_nao_nan.shape
# Out:
# (714, 12)

# %%
import os
import pandas as pd

caminho_arquivo = r"C:\_Repositorios\CienciaDeDadoseAnaliseGeoestatisticaComGeoprocessamento\Aula03\titanicexcel.xlsx"  # Use r para tratar as barras invertidas como literais

if os.path.exists(caminho_arquivo):
    titanic_excel = pd.read_excel(caminho_arquivo)
    print("funcionando")
else:
    print("não foi encontrado.")
# Out:
# funcionando

# %%
caminho_do_arquivo = r"C:\_Repositorios\CienciaDeDadoseAnaliseGeoestatisticaComGeoprocessamento\Aula03\titanicexcel.xlsx"

titanic_excel = pd.read_excel(caminho_arquivo)

# %%
titanic_excel.head()
# Out:
#    Id_Passageiro  Sobrevivente  Classe  \
# 0              1             0       3
# 1              2             1       1
# 2              3             1       3
# 3              4             1       1
# 4              5             0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                              Heikkinen, Miss Laina  female   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                           Allen, Mr. William Henry    male   35.0
#
#    Irmao_ou_Conjuge  Filhos          Ingresso   Tarifa Cabine Portao_embarque
# 0                 1       0         A/5 21171   7.2500    NaN               S
# 1                 1       0          PC 17599  71.2833    C85               C
# 2                 0       0  STON/O2. 3101282   7.9250    NaN               S
# ...

# %%
titanic["Idade"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
titanic[["Idade", "Tarifa"]].median()
# Out:
# Idade     28.0000
# Tarifa    14.4542
# dtype: float64

# %%
titanic[["Idade", "Tarifa"]].describe()
# Out:
#             Idade      Tarifa
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
titanic.agg(
    {
        "Idade": ["min", "max"],
        "Tarifa": ["min", "max", "mean"]
    }
)
# Out:
#       Idade      Tarifa
# min    0.42    0.000000
# max   80.00  512.329200
# mean    NaN   32.204208

# %%
titanic[["Sexo", "Idade"]].groupby("Sexo").mean()
# Out:
#             Idade
# Sexo
# female  27.915709
# male    30.726645
